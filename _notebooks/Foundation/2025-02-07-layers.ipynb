# %% [markdown]
# ---
# layout: post
# title: Computing System and Networks
# description:
# courses: {'csa': {'week': 23}}
# type: issues
# comments: true
# ---

# %% [markdown]
# <style>
#     table {
#         width: 100%;
#         border-collapse: collapse;
#     }
#     th, td {
#         border: 1px solid black;
#         padding: 10px;
#         text-align: left;
#     }
#     .dropdown-content {
#         display: none;
#         padding: 10px;
#         border: 1px solid #ccc;
#         margin-top: 5px;
#         background-color: #f9f9f9;
#     }
# </style>
# </head>
#     <table>
#         <tr>
#             <th>Layer</th>
#             <th>Component</th>
#             <th>More Info</th>
#         </tr>
#         <tr>
#             <td rowspan="3">Application Layer</td>
#             <td><button onclick="toggleDropdown('http-dns')">HTTP/DNS</button></td>
#             <td><div id="http-dns" class="dropdown-content">More info about HTTP/DNS</div></td>
#         </tr>
#         <tr>
#             <td><button onclick="toggleDropdown('frontend-github')">Frontend GitHub Pages</button></td>
#             <td><div id="frontend-github" class="dropdown-content">More info about Frontend GitHub Pages</div></td>
#         </tr>
#         <tr>
#             <td><button onclick="toggleDropdown('backend-aws')">Backend AWS EC2</button></td>
#             <td><div id="backend-aws" class="dropdown-content">More info about Backend AWS EC2</div></td>
#         </tr>
#         <tr>
#             <td rowspan="2">Transport Layer</td>
#             <td><button onclick="toggleDropdown('tcp-udp')">TCP/UDP</button></td>
#             <td><div id="tcp-udp" class="dropdown-content">More info about TCP/UDP</div></td>
#         </tr>
#         <tr>
#             <td><button onclick="toggleDropdown('nginx')">Nginx</button></td>
#             <td><div id="nginx" class="dropdown-content">More info about Nginx</div></td>
#         </tr>
#         <tr>
#             <td rowspan="2">Network Layer</td>
#             <td><button onclick="toggleDropdown('ip')">IP</button></td>
#             <td><div id="ip" class="dropdown-content">More info about IP</div></td>
#         </tr>
#         <tr>
#             <td><button onclick="toggleDropdown('routing')">Routing</button></td>
#             <td><div id="routing" class="dropdown-content">More info about Routing</div></td>
#         </tr>
#         <tr>
#             <td rowspan="2">Physical Layer</td>
#             <td><button onclick="toggleDropdown('ethernet')">Ethernet/Wi-Fi/Fiber</button></td>
#             <td><div id="ethernet" class="dropdown-content">More info about Ethernet/Wi-Fi/Fiber</div></td>
#         </tr>
#         <tr>
#             <td><button onclick="toggleDropdown('binary')">Binary Signals</button></td>
#             <td><div id="binary" class="dropdown-content">More info about Binary Signals</div></td>
#         </tr>
#     </table>
#     <script>
#         function toggleDropdown(id) {
#             var content = document.getElementById(id);
#             if (content.style.display === "block") {
#                 content.style.display = "none";
#             } else {
#                 content.style.display = "block";
#             }
#         }
#     </script>
