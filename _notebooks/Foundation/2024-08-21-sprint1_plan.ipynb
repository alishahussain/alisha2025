# %% [raw]
# ---
# layout: post
# title: Sprint 1 - Objectives
# description:  Tools and Software Development for Sprint 1
# type: issues
# comments: true
# ---

# %% [markdown]
# ## [Issue](https://github.com/nighthawkcoders/portfolio_2025/issues/14)

# %% [markdown]
# ## Project-base Learning Requirements
# Each sprint there will be hacks and project-based learning requirements.  It is up to the individual to develop their own plan for how they will represent work.  Here are some links and tips.
#
# - All work, tangible artifacts, will be captured in personal GitHub Pages
# - Tools and Software Development requirements are foundational requirements for all the CompSci courses.  Thus, they are shared, but listed under [CSSE Projects](https://github.com/orgs/nighthawkcoders/projects/15)
# - To obtain clarity on instructions you should start by picking a post in Sprint 1, then ask questions.
# - In Agile Development methodology, which we will learn throughout the course, an iteration (plans, designs, review references, coding) and questions should all be considered as part of your work.
# - Since iteraction and questions are part of your work, you should consider capturing and outlining iterations and questions in your blog.
# - Be aware, you will get more "Points" if you "Indicate" that you are progressing on a CompSci journey.
# - There are very few "Correct Answers" in this class! As you code, you will see that there is always more bugs and features.

# %% [markdown]
# ## Classroom Guidelines
# **It will be a very bad day when you say... "I have everything done".**  This statement typically comes by students that  are lacking understading.
#
# This statement shows that the person making the statement knows very little about CompSci and the principles of iteration that are being promoted in this class.  In fact, that state does not agree with Agile Development Methodologies that we will be learning in this class.
#
# The Teacher likes behaviors that are easily viewed and interpreted as productive to CompSci learning.
#
# - Code, Code, Code.  This is the process of making code and involves making plans, designs, reviewing references, asking questions and Code-Code-Coding.
# - No paper. We will be learning to do all work electronically.
# - Work Talk. A very high percentate 75%, 80% or more of your talk during class should be code, code, code talk.
# - Ears that can listen.  100% of time you should be available for discussion.  Covered or plugged in ears restricts hearing.
# - Hands that can code. The primary coding device is assumed to be your laptop!  Sprint 1 will be focused on laptop importance.
#
# [Read Learning Habits Table](https://github.com/nighthawkcoders/portfolio_2025/issues/14) to understand how behaviors will impact grading.

# %% [markdown]
# # **Sprint 5: UI and Data Usability Presentation**
#
# ## **1. Sprint Goals**
# - Focused on improving UI and data usability for **Toolkit** and **Gamify**.
# - Transition from consolidated code to feature-ready functionality.
# - Ensure seamless tracking using **Profile**, **Analytics**, and **Calendar** tools for **Slack Messages**.
#
# ---
#
# ## **2. Tasks Completed**
# - **UI Enhancements**:
#   - Improved styling for **Gamify** and Casino integration to create a cohesive user experience.
#   - Replaced user ID input with **email-based login** for better usability.
# - **Data Usability**:
#   - Fully integrated **JWT token** functionality to save user data persistently.
#   - Adjusted backend API to work seamlessly with the **person API**, ensuring compatibility with the larger project.
# - **Toolkit Progress**:
#   - Leveraged Toolkit for tracking items discussed to the end of the year.
#
# *(Visual: Include screenshots of the new UI, updated backend logic, or flow diagrams showing JWT integration)*
#
# ---
#
# ## **3. Challenges Encountered**
# - **Styling Issues**:
#   - Matching the style across different games required extensive collaboration and iteration.
#   - **Solution**: Created a unified design language to maintain consistency.
# - **Backend Adjustments**:
#   - Transitioning from user API to person API was complex but necessary for integration.
#   - **Solution**: Collaborated with teammates and utilized existing documentation to resolve mapping issues.
#
# ---
#
# ## **4. Key Accomplishments**
# - **JWT Implementation**:
#   - Enabled data persistence by integrating JWT tokens with the email-based login system.
# - **Collaboration**:
#   - Actively communicated with peers across different periods and groups to address integration challenges.
#   - Achieved greater synergy through collaborative debugging sessions.
# - **UI Enhancements**:
#   - Introduced sliders for **balance adjustments**, improving usability by syncing with the stock game’s scaling logic.
#
# *(Visual: Show a before-and-after comparison of UI features like the slider and updated styling.)*
#
# ---
#
# ## **5. Pending Tasks**
# - **Final Testing**:
#   - Submit pull request to the teacher repository and ensure functionality across all modules.
# - **Styling Improvements**:
#   - Refine the styling to better align with the overall project theme.
# - **Integration Validation**:
#   - Conduct end-to-end testing to confirm data is being saved and retrieved accurately.
#
# ---
#
# ## **6. Retrospective**
# - **What Went Well**:
#   - Successfully mapped APIs, resolving multiple integration challenges.
#   - Enhanced user experience with meaningful UI changes and seamless data tracking.
# - **What Could Be Improved**:
#   - Earlier collaboration on design and backend standards to avoid redundant iterations.
#   - Streamlining communication to prevent overlapping changes.
#
# ---
#
# ## **7. Visual Roadmap for Future Sprints**
# - **February**:
#   - Finalize and review all project integrations.
#   - Implement **leaderboard** and analytics functionality for the games.
# - **March**:
#   - Prepare for AP exam content integration, focusing on Data Structures and algorithms.
# - **April**:
#   - Refine project for final presentation at **N@tM**.
#   - Conduct mock interviews and project reviews.
#
# *(Visual: Add a Gantt chart or timeline with milestones.)*
#
# ---
#
# ## **Call to Action**
# - **Feedback**: Request feedback from teammates and mentors on the updated functionality and UI.
# - **Next Steps**: Push the pending pull request and complete final styling adjustments.
